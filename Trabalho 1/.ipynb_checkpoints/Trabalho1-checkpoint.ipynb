# %% [markdown]
# # Trabalho 1 - Perceptron Multicamada

# %% [markdown]
# #### Antes de começar a definição dos modelos em si, devemos garantir que conseguimos carregar e ler a base de dados adequadamente.

# %%
from torchvision import datasets
from torchvision import transforms 
from torch.utils.data import DataLoader 
from torch import nn
import torch.nn.functional as F
import torch
from d2l import torch as d2l
import matplotlib.pyplot as plt

RANDOM_SEED= 123
LEARNING_RATE = 0.1
NUM_EPOCHS = 10
NUM_EPOCHS_DOUBLE = 20
BATCH_SIZE = 64

if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
    torch.cuda.manual_seed(RANDOM_SEED)
else:
    DEVICE = torch.device("cpu")
    torch.manual_seed(RANDOM_SEED)
        
print('Using',DEVICE)

def one_hot_encode(labels, num_classes):
    return torch.eye(num_classes)[labels]

class MNIST(d2l.DataModule):
    def __init__(self, batch_size=BATCH_SIZE):
        super().__init__()
        self.save_hyperparameters()
        self.batch_size = batch_size
        self.transform = d2l.transforms.Compose([
            d2l.transforms.ToTensor()])
        self.train_set = datasets.MNIST(root='data',
                               train=True,
                               transform=transforms.ToTensor(),
                               download=True)
        self.val_set = datasets.MNIST(root='data', 
                              train=False,
                              transform=transforms.ToTensor())
        
    def get_dataloader(self, train):
        data = self.train_set if train else self.val_set
        return DataLoader(data, self.batch_size, shuffle=train)
        
data = MNIST()
print(f"Training dataset size: {len(data.train_set)}")
print(f"Validation dataset size: {len(data.val_set)}")
print(data.train_set[0][0].shape)
image_numpy = data.train_set[0][0].permute(1, 2, 0).cpu().numpy()
plt.imshow(image_numpy)
print(f"Image label: {data.train_set[0][1]}")
# Out:
# Using cpu
# Training dataset size: 60000
# Validation dataset size: 10000
# torch.Size([1, 28, 28])
# Image label: 5

# %%
x, y = next(iter(data.train_dataloader()))
print(x.shape, x.dtype, y.shape, y.dtype)
# Out:
# torch.Size([64, 1, 28, 28]) torch.float32 torch.Size([64]) torch.int64

# %% [markdown]
# #### Como a leitura dos dados ocorreu como o desejado podemos seguir para a definição dos modelos.

# %% [markdown]
# ## 2a) Perceptron com uma camada escondida, função de ativação logística, função custo SSE e otimização por descida de gradiente

# %%
class MLP2a(d2l.Classifier):
    def __init__(self, num_outputs, num_hiddens, lr):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.LazyLinear(num_hiddens),
            nn.Sigmoid(),
            nn.LazyLinear(num_outputs),
            nn.Sigmoid()
        )
        
    def loss(self, y_hat, y):
        y_one_hot = one_hot_encode(y, y_hat.size(-1)).to(y_hat.device)
        fn = nn.MSELoss()
        return fn(y_hat, y_one_hot)
    
    def configure_optimizers(self):
        return torch.optim.SGD(self.parameters(), self.lr)

model = MLP2a(num_outputs=10, num_hiddens=128, lr=LEARNING_RATE)
trainer = d2l.Trainer(max_epochs=NUM_EPOCHS,)
trainer.fit(model, data)

# %%
test_acc = d2l.evaluate_accuracy_gpu(model, data.val_dataloader())
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# Test accuracy: 74.91%

# %% [markdown]
# #### Para o treinamento foi definido um numero padrão de épocas como 10. Há casos, como visto acima, em que a curva de acurácia ainda aparenta seguir crescendo. Em casos como esse, dobramos o número de épocas e treinamos o modelo novamente.

# %%
model = MLP2a(num_outputs=10, num_hiddens=128, lr=LEARNING_RATE)
trainer = d2l.Trainer(max_epochs=NUM_EPOCHS_DOUBLE,)
trainer.fit(model, data)

# %%
test_acc = d2l.evaluate_accuracy_gpu(model, data.val_dataloader())
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# Test accuracy: 86.79%

# %% [markdown]
# #### Podemos perceber que a acurácia seguiu melhorando após a época 10. Houve um aumento significativo na acurácia final do modelo e, talvez, com mais épocas de treinamento seria possível melhorar o modelo ainda mais.

# %% [markdown]
# ## 2b) Saída do tipo softmax, custo "entropia cruzada"

# %%
class MLP2b(d2l.Classifier):
    def __init__(self, num_outputs, num_hiddens, lr):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.LazyLinear(num_hiddens),
            nn.Sigmoid(),
            nn.LazyLinear(num_outputs),
            nn.Softmax()
        )
    
    def configure_optimizers(self):
        return torch.optim.SGD(self.parameters(), self.lr)

model = MLP2b(num_outputs=10, num_hiddens=128, lr=LEARNING_RATE)
trainer = d2l.Trainer(max_epochs=NUM_EPOCHS,)
trainer.fit(model, data)

# %%
test_acc = d2l.evaluate_accuracy_gpu(model, data.val_dataloader())
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# Test accuracy: 84.32%

# %% [markdown]
# #### Para esse segundo modelo também não há estagnação clara na curva. Para entender melhor foi feito novamente o treinamento com o dobro de épocas. É possível notar que esse modelo está com maior acurácia que o anterior para o primeiro treinamento.

# %%
model = MLP2b(num_outputs=10, num_hiddens=128, lr=LEARNING_RATE)
trainer = d2l.Trainer(max_epochs=NUM_EPOCHS_DOUBLE,)
trainer.fit(model, data)

# %%
test_acc = d2l.evaluate_accuracy_gpu(model, data.val_dataloader())
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# Test accuracy: 91.82%

# %% [markdown]
# #### Foi obtido um resultado parecido com o do modelo anterior, havendo aumento significativo na acurácia com o aumento do número de épocas.

# %% [markdown]
# ## 2c) Otimizador Adam

# %%
class MLP2c(d2l.Classifier):
    def __init__(self, num_outputs, num_hiddens, lr):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.LazyLinear(num_hiddens),
            nn.Sigmoid(),
            nn.LazyLinear(num_outputs),
            nn.Softmax()
        )
    
    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), self.lr)

model = MLP2c(num_outputs=10, num_hiddens=128, lr=LEARNING_RATE)
trainer = d2l.Trainer(max_epochs=NUM_EPOCHS,)
trainer.fit(model, data)

# %%
test_acc = d2l.evaluate_accuracy_gpu(model, data.val_dataloader())
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# Test accuracy: 30.51%

# %% [markdown]
# #### Inicialmente, quando treinamos o modelo com o otimizador ADAM ele parece não responder a nenhuma etapa do treinamento. É possível que a taxa de aprendizado esteja inadequada para esse novo otimizador. A taxa foi ajustada para 0.01, 10 vezes menos que a utilizada anteriormente.

# %%
LEARNING_RATE = 0.01
model = MLP2c(num_outputs=10, num_hiddens=128, lr=LEARNING_RATE)
trainer = d2l.Trainer(max_epochs=NUM_EPOCHS,)
trainer.fit(model, data)

# %%
test_acc = d2l.evaluate_accuracy_gpu(model, data.val_dataloader())
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# Test accuracy: 96.93%

# %% [markdown]
# #### Após o ajuste na taxa de aprendizado obtivemos um resultado satisfatório, sendo esse modelo o mais eficiente até agora. Com taxa de acurácia acima de 95% e uma aparente estagnação na curva de perda não há necessidade de treinar o modelo com mais épocas.

# %% [markdown]
# ## 2d) A função Relu

# %%
class MLP2d(d2l.Classifier):
    def __init__(self, num_outputs, num_hiddens, lr):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.LazyLinear(num_hiddens),
            nn.ReLU(),
            nn.LazyLinear(num_outputs),
            nn.Softmax()
        )
    
    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), self.lr)

model = MLP2d(num_outputs=10, num_hiddens=128, lr=LEARNING_RATE)
trainer = d2l.Trainer(max_epochs=NUM_EPOCHS,)
trainer.fit(model, data)

# %%
test_acc = d2l.evaluate_accuracy_gpu(model, data.val_dataloader())
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# Test accuracy: 94.18%

# %% [markdown]
# #### A mudança de função de ativação da camada escondida para a função ReLu não parece ter tido mudança significativa na acurácia para esse modelo. Ao observar a curva, o ponto de acurácia mais alto parece ter sido na época 7, com flutuações após. Para entender melhor, Treinou-se o modelo novamente com o dobro de épocas.

# %%
model = MLP2d(num_outputs=10, num_hiddens=128, lr=LEARNING_RATE)
trainer = d2l.Trainer(max_epochs=NUM_EPOCHS_DOUBLE,)
trainer.fit(model, data)

# %%
test_acc = d2l.evaluate_accuracy_gpu(model, data.val_dataloader())
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# Test accuracy: 95.42%

# %% [markdown]
# #### O modelo já estava com acurácia muito alta, então não havia muito a ser melhorado. Foi possível apenas confirmar que a acurácia do modelo já estava estável com 10 épocas.

# %% [markdown]
# ## 2e)Redes Maiores

# %% [markdown]
# ### **Uma camada escondida com 256 neurônios**

# %%
model = MLP2d(num_outputs=10, num_hiddens=256, lr=LEARNING_RATE)
trainer = d2l.Trainer(max_epochs=NUM_EPOCHS,)
trainer.fit(model, data)

# %%
test_acc = d2l.evaluate_accuracy_gpu(model, data.val_dataloader())
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# Test accuracy: 94.71%

# %% [markdown]
# #### Ao aumentar o número de neurônios na camada escondida para 256 o desempenho do modelo foi praticamente igual ao do modelo com 128 neurônios.

# %% [markdown]
# ### **Duas camadas escondidas com 128 neurônios**

# %%
class MLP2e(d2l.Classifier):
    def __init__(self, num_outputs, num_hiddens, lr):
        super().__init__()
        self.save_hyperparameters()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.LazyLinear(num_hiddens),
            nn.ReLU(),
            nn.LazyLinear(num_hiddens),
            nn.ReLU(),
            nn.LazyLinear(num_outputs),
            nn.Softmax()
        )
    
    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), self.lr)

model = MLP2e(num_outputs=10, num_hiddens=128, lr=LEARNING_RATE)
trainer = d2l.Trainer(max_epochs=NUM_EPOCHS,)
trainer.fit(model, data)

# %%
test_acc = d2l.evaluate_accuracy_gpu(model, data.val_dataloader())
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# Test accuracy: 82.66%

# %% [markdown]
# #### Quando comparado aos últimos modelos, que obtiveram acurácia acima de 90%, esse modelo de duas camadas escondidas teve desempenho abaixo do esperado. Nota-se mudança de direção da curva em cada época de treinamento. Em um caso assim é possível supor que a taxa de aprendizado esteja alta demais e a cada passada ele ultrapassa seu objetivo. Para testar essa hipótese foi reduzido para 0.001 a taxa de aprendizado do modelo.

# %%
model = MLP2e(num_outputs=10, num_hiddens=128, lr=0.001)
trainer = d2l.Trainer(max_epochs=NUM_EPOCHS,)
trainer.fit(model, data)

# %%
test_acc = d2l.evaluate_accuracy_gpu(model, data.val_dataloader())
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# Test accuracy: 97.18%

# %% [markdown]
# #### Após a mudança na taxa de atualização o modelo de duas camadas escondidas apresentou o melhor desempenho entre todos os modelos treinados.

# %% [markdown]
# ## 3. Visualização

# %%
def visualize_misclassified(model, data, device, n_examples=5):
    """
    Visualiza exemplos mal-classificados do modelo no conjunto de validação.
    
    Parâmetros:
        model (d2l.Classifier): O modelo treinado.
        data (MNIST): O objeto de dados contendo os conjuntos de treino e validação.
        device (torch.device): Dispositivo CPU ou GPU.
        n_examples (int): Número de exemplos mal-classificados a serem exibidos.
    """
    # Coloca o modelo em modo de avaliação
    model.eval()
    misclassified = []

    # Dataloader do conjunto de validação
    val_loader = data.val_dataloader()

    # Passa por todos os batches do conjunto de validação
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)  # Predições do modelo
            incorrect = (predicted != labels).nonzero(as_tuple=True)[0]

            # Armazena os exemplos mal-classificados
            for idx in incorrect:
                misclassified.append((images[idx].cpu(), labels[idx].item(), predicted[idx].item()))

            # Interrompe quando atingir o número desejado
            if len(misclassified) >= n_examples:
                break

    # Exibe os exemplos mal-classificados
    n_display = min(len(misclassified), n_examples)
    fig, axes = plt.subplots(1, n_display, figsize=(10, 5))
    fig.suptitle("Exemplos mal-classificados", fontsize=16)

    for i, (img, true_label, pred_label) in enumerate(misclassified[:n_display]):
        # Transforma a imagem para exibição
        img = img.numpy().squeeze()
        axes[i].imshow(img, cmap="gray")
        axes[i].axis("off")
        axes[i].set_title(f"Esperado: {true_label}\nObtido: {pred_label}")

    plt.show()

# %%
# Visualiza exemplos mal-classificados
visualize_misclassified(model, data, DEVICE, n_examples=5)

# %% [markdown]
# #### Dentre os exemplos classificados incorretamente, há alguns que provavelmente seriam confundidos mais facilmente por um ser humano do que outros. Em especial, os exemplos entre 6:0 e 9:1 parecem ser mais passíveis a confusão. Para saber se há um padrão entre esses exmplos mal classificados será desenhada a matriz de confusão a seguir.

# %% [markdown]
# ## 4. Matriz de confusão

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

def plot_confusion_matrix(model, data, device):
    """
    Calcula e exibe a matriz de confusão para o conjunto de validação.

    Parâmetros:
        model (d2l.Classifier): O modelo treinado.
        data (MNIST): O objeto contendo os conjuntos de dados.
        device (torch.device): O dispositivo (CPU ou GPU).
    """
    # Coloca o modelo em modo de avaliação
    model.eval()
    
    # Listas para armazenar os rótulos verdadeiros e as predições
    all_labels = []
    all_preds = []

    # DataLoader do conjunto de validação
    val_loader = data.val_dataloader()

    # Itera sobre os batches do conjunto de validação
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            
            # Armazena os rótulos verdadeiros e as predições
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())

    # Calcula a matriz de confusão
    conf_matrix = confusion_matrix(all_labels, all_preds, labels=np.arange(10))

    # Exibe a matriz de confusão usando Seaborn
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=np.arange(10), yticklabels=np.arange(10))
    plt.title("Matriz de Confusão")
    plt.xlabel("Predição")
    plt.ylabel("Rótulo Verdadeiro")
    plt.show()

# %%
# Exibe a matriz de confusão do modelo treinado
plot_confusion_matrix(model, data, DEVICE)

# %% [markdown]
# #### Após a análise da matriz de confusão parecebe-se que um caso é consideravelmente mais confundido que os demais. A maior confusão foi o número 4 ser classificado como 9. Essa confusão é plausível de ser feita por um ser humano também a depender do exemplo. Os outros casos relevantes de confusão, embora em menos ocorrência são 7:2, 8:3 e 9:4, sendo o primeiro número o rótulo verdadeiro e o segundo a predição. É fácil imaginar a confusão entre todos esses casos, e nota-se que há confusão tanto entre 9:4 e 4:9.

# %% [markdown]
# #### Após todos os testes, o modelo de melhor desempenho foi o modelo de duas camadas escondidas de 128 neurônios.
